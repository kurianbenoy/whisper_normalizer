# %% [raw]
# ---
# description: OpenAI's Whisper Normalizer implementation
# output-file: english.html
# title: WhisperNormalizer English Module
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(EnglishSpellingNormalizer)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/whisper_normalizer/blob/main/whisper_normalizer/english.py#L456){target="_blank" style="float:right; font-size:smaller"}
#
# ### EnglishSpellingNormalizer
#
# >      EnglishSpellingNormalizer ()
#
# Applies British-American spelling mappings as listed in [1].
#
# [1] https://www.tysto.com/uk-us-spelling-list.html

# %%
#| echo: false
#| output: asis
show_doc(EnglishNumberNormalizer)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/whisper_normalizer/blob/main/whisper_normalizer/english.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### EnglishNumberNormalizer
#
# >      EnglishNumberNormalizer ()
#
# Convert any spelled-out numbers into arabic numbers, while handling:
#
# - remove any commas
# - keep the suffixes such as: `1960s`, `274th`, `32nd`, etc.
# - spell out currency symbols after the number. e.g. `$20 million` -> `20000000 dollars`
# - spell out `one` and `ones`
# - interpret successive single-digit numbers as nominal: `one oh one` -> `101`

# %%
#| echo: false
#| output: asis
show_doc(EnglishTextNormalizer)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/whisper_normalizer/blob/main/whisper_normalizer/english.py#L473){target="_blank" style="float:right; font-size:smaller"}
#
# ### EnglishTextNormalizer
#
# >      EnglishTextNormalizer ()
#
# Initialize self.  See help(type(self)) for accurate signature.
