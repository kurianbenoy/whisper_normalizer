# %% [raw]
# ---
# description: OpenAI's Whisper Normalizer implementation
# output-file: basic.html
# title: WhisperNormalizer Base Module
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(remove_symbols)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/whisper_normalizer/blob/main/whisper_normalizer/basic.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### remove_symbols
#
# >      remove_symbols (s:str)
#
# Replace any other markers, symbols, punctuations with a space, keeping diacritics

# %%
#| echo: false
#| output: asis
show_doc(remove_symbols_and_diacritics)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/whisper_normalizer/blob/main/whisper_normalizer/basic.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### remove_symbols_and_diacritics
#
# >      remove_symbols_and_diacritics (s:str, keep='')
#
# Replace any other markers, symbols, and punctuations with a space,
# and drop any diacritics (category 'Mn' and some manual mappings)

# %%
#| echo: false
#| output: asis
show_doc(BasicTextNormalizer)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/whisper_normalizer/blob/main/whisper_normalizer/basic.py#L62){target="_blank" style="float:right; font-size:smaller"}
#
# ### BasicTextNormalizer
#
# >      BasicTextNormalizer (remove_diacritics:bool=False,
# >                           split_letters:bool=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Testing Basic Normalizer

# %%
normalizer = BasicTextNormalizer()
